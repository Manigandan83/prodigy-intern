# %%
                                     First task: Make a bar chart to show the population

# %%
Step 1: Import the Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as

# %%
Step 2: load Dataset

# %%
#load the dataset 
dataset = pd.read_excel('C:/Users/manig/Downloads/archive (2)/Population of the Republic of Kazakhstan by gender and type of locality (as of July 1 2024).xlsx')

# to view the dataset head
dataset.head()
# Out:
#             region  Total population       men     women urban_population  \
# 0             Abay          605872.0  297009.0  308863.0           373139
# 1       Semei с.а.          311694.0  149017.0  162677.0           311604
# 2   Кurchatov с.а.           10217.0    4987.0    5230.0            10217
# 3    Abai district           13756.0    6906.0    6850.0                -
# 4  Aksuat district           19128.0    9826.0    9302.0                -
#
#   urban_population_men urban_population_women rural_population  \
# 0               179250                 193889           232733
# 1               148967                 162637               90
# 2                 4987                   5230                -
# 3                    -                      -            13756
# 4                    -                      -            19128
#
#   rural_population_men rural_population_women
# 0               117759                 114974
# 1                   50                     40
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   region                  247 non-null    object
#  1   Total population        247 non-null    float64
#  2   men                     247 non-null    float64
#  3   women                   247 non-null    float64
#  4   urban_population        247 non-null    object
#  5   urban_population_men    247 non-null    object
#  6   urban_population_women  247 non-null    object
#  7   rural_population        247 non-null    object
#  8   rural_population_men    247 non-null    object
#  9   rural_population_women  247 non-null    object
# dtypes: float64(3), object(7)
# memory usage: 20.9+ KB

# %%
dataset.describe()
# Out:
#        Total population           men         women
# count      2.470000e+02  2.470000e+02  2.470000e+02
# mean       1.632365e+05  7.973989e+04  8.349660e+04
# std        3.076256e+05  1.497492e+05  1.580733e+05
# min        5.092000e+03  2.621000e+03  2.426000e+03
# 25%        2.160500e+04  1.111950e+04  1.057400e+04
# 50%        4.379400e+04  2.218200e+04  2.185900e+04
# 75%        1.703445e+05  8.519950e+04  8.373250e+04
# max        2.258251e+06  1.096910e+06  1.207812e+06

# %% [raw]
# Step 3: Data Cleaning Process

# %%
new_df = dataset.dropna(how='all')

# Print the cleaned DataFrame
print(new_df)
# Out:
#                  region  Total population       men     women  \
# 0                  Abay          605872.0  297009.0  308863.0
# 1            Semei с.а.          311694.0  149017.0  162677.0
# 2        Кurchatov с.а.           10217.0    4987.0    5230.0
# 3         Abai district           13756.0    6906.0    6850.0
# 4       Aksuat district           19128.0    9826.0    9302.0
# ..                  ...               ...       ...       ...
# 261       Abay district          230468.0  111427.0  119041.0
# 262  Al-Farabi district          268684.0  127103.0  141581.0
# 263   Enbekshi district          205214.0   98507.0  106707.0
# 264    Karatau district          301428.0  148686.0  152742.0
# 265      Turan district          233174.0  113382.0  119792.0
#
#     urban_population urban_population_men urban_population_women  \
# 0             373139               179250                 193889
# 1             311604               148967                 162637
# ...

# %%
print(dataset.columns)
# Out:
# Index(['region', 'Total population', 'men', 'women', 'urban_population',
#        'urban_population_men', 'urban_population_women', 'rural_population',
#        'rural_population_men', 'rural_population_women'],
#       dtype='object')

# %%
# Population distribution by gender
plt.figure(figsize=(6, 6))
new_df[['men', 'women']].sum().plot(kind='bar', color=['darkblue', 'pink'])
plt.title('Total Population by Gender')
plt.ylabel('Population')
plt.show()

# %%
                                   Second task: Data Cleaning Process

# %%
Step 1: Import the Libraries

# %%
# import the libraries
import pandas as pd

# %%
Step 2: Load Dataset

# %%
# load the dataset
dataset = pd.read_csv("C:\\Users\\manig\\Downloads\\archive (3)\\laptopData.csv")
print(dataset)
# Out:
#       Unnamed: 0 Company            TypeName Inches  \
# 0            0.0   Apple           Ultrabook   13.3
# 1            1.0   Apple           Ultrabook   13.3
# 2            2.0      HP            Notebook   15.6
# 3            3.0   Apple           Ultrabook   15.4
# 4            4.0   Apple           Ultrabook   13.3
# ...          ...     ...                 ...    ...
# 1298      1298.0  Lenovo  2 in 1 Convertible     14
# 1299      1299.0  Lenovo  2 in 1 Convertible   13.3
# 1300      1300.0  Lenovo            Notebook     14
# 1301      1301.0      HP            Notebook   15.6
# 1302      1302.0    Asus            Notebook   15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %%
# Step 3: data cleaning process

# %%
# in datacleaning process there is remove the empty values 
new_dataset = dataset.dropna()
new_dataset
print(new_dataset.to_string())
# Out:
#       Unnamed: 0    Company            TypeName Inches                               ScreenResolution                                    Cpu   Ram                         Memory                             Gpu         OpSys    Weight        Price
# 0            0.0      Apple           Ultrabook   13.3             IPS Panel Retina Display 2560x1600                   Intel Core i5 2.3GHz   8GB                      128GB SSD    Intel Iris Plus Graphics 640         macOS    1.37kg   71378.6832
# 1            1.0      Apple           Ultrabook   13.3                                       1440x900                   Intel Core i5 1.8GHz   8GB            128GB Flash Storage          Intel HD Graphics 6000         macOS    1.34kg   47895.5232
# 2            2.0         HP            Notebook   15.6                              Full HD 1920x1080             Intel Core i5 7200U 2.5GHz   8GB                      256GB SSD           Intel HD Graphics 620         No OS    1.86kg   30636.0000
# ...

# %% [markdown]
#                                  Third task: Decision Tree Algorithm in classifier

# %% [markdown]
# Step 1: Import the Libraries

# %%
# import the library for decision tree algorithm (classifier)
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler  # Corrected to StandardScaler
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# Step 2: load the dataset

# %%
# Load the dataset
dataset = pd.read_csv("C:\\Users\\manig\\Downloads\\student_ML_dataset\\student_ML_dataset\\Dataset\\Iris_new.csv")

# Define X (independent variables) and y (dependent variable)
x = dataset.iloc[:, 0:4].values  # Assuming the first four columns are features
y = dataset.iloc[:, -1].values    # Assuming the last column is the target variable

# %% [markdown]
# Step 3: Splitting the Dataset

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=0)

# %% [markdown]
# Step 3: Feature Scaling

# %%
sc= StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.fit_transform(x_test)

# %% [markdown]
# Step 4: Train the Dataset using DecisionTree Classifier Model

# %%
classifier = DecisionTreeClassifier(criterion='entropy',random_state=0)
classifier.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=0)

# %% [markdown]
# Step 5: Predicting the Testset Results

# %%
y_pred = classifier.predict(x_test)
print(y_pred)
# Out:
# ['virginica' 'versicolor' 'setosa' 'virginica' 'setosa' 'virginica'
#  'setosa' 'versicolor' 'virginica' 'versicolor' 'virginica' 'versicolor'
#  'versicolor' 'versicolor' 'versicolor' 'setosa' 'versicolor' 'versicolor'
#  'setosa' 'setosa' 'virginica' 'versicolor' 'setosa' 'setosa' 'virginica'
#  'setosa' 'setosa' 'versicolor' 'versicolor' 'setosa' 'virginica'
#  'versicolor' 'setosa' 'virginica' 'virginica' 'versicolor' 'setosa'
#  'versicolor']

# %% [markdown]
# Step 6: Making Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test,y_pred)
print(cm)
# Out:
# [[13  0  0]
#  [ 0 15  1]
#  [ 0  0  9]]

# %% [markdown]
# Step 7: Find the accuracy

# %%
acc = (sum(np.diag(cm))/len(y_test))
print(acc)
# Out:
# 0.9736842105263158

# %% [markdown]
# Step 8:lets Visualize the decisionTree Classifier

# %%
from sklearn.tree import plot_tree
plt.figure(dpi=300)
feature_col = dataset
featrure_col = feature_col.drop("spectype",axis=1)
decision_tree = plot_tree(decision_tree = classifier,max_depth=3,feature_names=feature_col.columns,
                          class_names=['setosa','vercicolor','virginica'],filled=True,
                          precision=1,rounded=True,fontsize=4)
plt.show()
